# %% [markdown]
# # Review Spacy
#
# General Package Details.
#
# References:
#  * [Spacy Guides](https://spacy.io/usage)
#  * [Spacy Examles](https://spacy.io/usage/examples)
#  * [Real Python](https://realpython.com/natural-language-processing-spacy-python/)

# %%
import spacy

# %%
#Version
print(spacy.__version__)
# Out:
# 2.2.3

# %% [markdown]
# ## Linguistic Features
#
# Put in raw text, and get back a **Doc** object, that comes with a variety of annotations.

# %% [markdown]
# ## Part-of-speech tagging
#
# After tokenization, spaCy can parse and tag a given Doc. Like many NLP libraries, spaCy encodes all strings to [hash values](https://en.wikipedia.org/wiki/Hash_function) to reduce memory usage and improve efficiency.

# %%
nlp=spacy.load("en_core_web_sm")

# %%
text=open("data/glossary_ML.txt").read()

# %%
print(text)
# Out:
# A/B testing
# A statistical way of comparing two (or more) techniques, typically an incumbent against a new rival. A/B testing aims to determine not only which technique performs better but also to understand whether the difference is statistically significant. A/B testing usually considers only two techniques using one measurement, but it can be applied to any finite number of techniques and measures.
#
# accuracy
# The fraction of predictions that a classification model got right. In multi-class classification, accuracy is defined as follows:
#
# In binary classification, accuracy has the following definition:
#
# See true positive and true negative.
#
# action
# #rl
# In reinforcement learning, the mechanism by which the agent transitions between states of the environment. The agent chooses the action by using a policy.
#
# activation function
# A function (for example, ReLU or sigmoid) that takes in the weighted sum of all of the inputs from the previous layer and then generates and passes an output value (typically nonlinear) to the next layer.
#
# active learning
# A training approach in which the algorithm chooses some of the data it learns from. Active learning is particularly valuable when labeled examples are scarce or expensive to obtain. Instead of blindly seeking a diverse range of labeled examples, an active learning algorithm selectively seeks the particular range of examples it needs for learning.
#
# AdaGrad
# A sophisticated gradient descent algorithm that rescales the gradients of each parameter, effectively giving each parameter an independent learning rate. For a full explanation, see this paper.
#
# agent
# #rl
# In reinforcement learning, the entity that uses a policy to maximize expected return gained from transitioning between states of the environment.
#
# agglomerative clustering
# See hierarchical clustering.
#
# AR
# Abbreviation for augmented reality.
#
# area under the PR curve
# See PR AUC (Area under the PR Curve).
#
# area under the ROC curve
# See AUC (Area under the ROC curve).
#
# artificial general intelligence
# A non-human mechanism that demonstrates a broad range of problem solving, creativity, and adaptability. For example, a program demonstrating artificial general intelligence could translate text, compose symphonies, and excel at games that have not yet been invented.
#
# artificial intelligence
# A non-human program or model that can solve sophisticated tasks. For example, a program or model that translates text or a program or model that identifies diseases from radiologic images both exhibit artificial intelligence.
#
# Formally, machine learning is a sub-field of artificial intelligence. However, in recent years, some organizations have begun using the terms artificial intelligence and machine learning interchangeably.
#
# attribute
# #fairness
# Synonym for feature. In fairness, attributes often refer to characteristics pertaining to individuals.
#
# AUC (Area under the ROC Curve)
# An evaluation metric that considers all possible classification thresholds.
#
# The Area Under the ROC curve is the probability that a classifier will be more confident that a randomly chosen positive example is actually positive than that a randomly chosen negative example is positive.
#
# augmented reality
# A technology that superimposes a computer-generated image on a user's view of the real world, thus providing a composite view.
#
# automation bias
# #fairness
# When a human decision maker favors recommendations made by an automated decision-making system over information made without automation, even when the automated decision-making system makes errors.
#
# average precision
# A metric for summarizing the performance of a ranked sequence of results. Average precision is calculated by taking the average of the precision values for each relevant result (each result in the ranked list where the recall increases relative to the previous result).
#
# See also Area under the PR Curve.
#
# B
# backpropagation
# The primary algorithm for performing gradient descent on neural networks. First, the output values of each node are calculated (and cached) in a forward pass. Then, the partial derivative of the error with respect to each parameter is calculated in a backward pass through the graph.
#
# bag of words
# A representation of the words in a phrase or passage, irrespective of order. For example, bag of words represents the following three phrases identically:
#
# the dog jumps
# jumps the dog
# dog jumps the
# Each word is mapped to an index in a sparse vector, where the vector has an index for every word in the vocabulary. For example, the phrase the dog jumps is mapped into a feature vector with non-zero values at the three indices corresponding to the words the, dog, and jumps. The non-zero value can be any of the following:
#
# A 1 to indicate the presence of a word.
# A count of the number of times a word appears in the bag. For example, if the phrase were the maroon dog is a dog with maroon fur, then both maroon and dog would be represented as 2, while the other words would be represented as 1.
# Some other value, such as the logarithm of the count of the number of times a word appears in the bag.
# baseline
# A model used as a reference point for comparing how well another model (typically, a more complex one) is performing. For example, a logistic regression model might serve as a good baseline for a deep model.
#
# For a particular problem, the baseline helps model developers quantify the minimal expected performance that a new model must achieve for the new model to be useful.
#
# batch
# The set of examples used in one iteration (that is, one gradient update) of model training.
#
# See also batch size.
#
# batch normalization
# Normalizing the input or output of the activation functions in a hidden layer. Batch normalization can provide the following benefits:
#
# Make neural networks more stable by protecting against outlier weights.
# Enable higher learning rates.
# Reduce overfitting.
# batch size
# The number of examples in a batch. For example, the batch size of SGD is 1, while the batch size of a mini-batch is usually between 10 and 1000. Batch size is usually fixed during training and inference; however, TensorFlow does permit dynamic batch sizes.
#
# Bayesian neural network
# A probabilistic neural network that accounts for uncertainty in weights and outputs. A standard neural network regression model typically predicts a scalar value; for example, a model predicts a house price of 853,000. By contrast, a Bayesian neural network predicts a distribution of values; for example, a model predicts a house price of 853,000 with a standard deviation of 67,200. A Bayesian neural network relies on Bayes' Theorem to calculate uncertainties in weights and predictions. A Bayesian neural network can be useful when it is important to quantify uncertainty, such as in models related to pharmaceuticals. Bayesian neural networks can also help prevent overfitting.
#
# Bellman equation
# #rl
# In reinforcement learning, the following identity satisfied by the optimal Q-function:
#
# Reinforcement learning algorithms apply this identity to create Q-learning via the following update rule:
#
# Beyond reinforcement learning, the Bellman equation has applications to dynamic programming. See the Wikipedia entry for Bellman Equation.
#
# bias (ethics/fairness)
# #fairness
# 1. Stereotyping, prejudice or favoritism towards some things, people, or groups over others. These biases can affect collection and interpretation of data, the design of a system, and how users interact with a system. Forms of this type of bias include:
#
# automation bias
# confirmation bias
# experimenter’s bias
# group attribution bias
# implicit bias
# in-group bias
# out-group homogeneity bias
# 2. Systematic error introduced by a sampling or reporting procedure. Forms of this type of bias include:
#
# coverage bias
# non-response bias
# participation bias
# reporting bias
# sampling bias
# selection bias
# Not to be confused with the bias term in machine learning models or prediction bias.
#
# bias (math)
# An intercept or offset from an origin. Bias (also known as the bias term) is referred to as b or w0 in machine learning models. For example, bias is the b in the following formula:
#
# Not to be confused with bias in ethics and fairness or prediction bias.
#
# bigram
# An N-gram in which N=2.
#
# binary classification
# A type of classification task that outputs one of two mutually exclusive classes. For example, a machine learning model that evaluates email messages and outputs either "spam" or "not spam" is a binary classifier.
#
# binning
# See bucketing.
#
# boosting
# A machine learning technique that iteratively combines a set of simple and not very accurate classifiers (referred to as "weak" classifiers) into a classifier with high accuracy (a "strong" classifier) by upweighting the examples that the model is currently misclassfying.
#
# bounding box
# In an image, the (x, y) coordinates of a rectangle around an area of interest, such as the dog in the image below.
#
# Photograph of a dog sitting on a sofa. A green bounding box
#           with top-left coordinates of (275, 1271) and bottom-right
#           coordinates of (2954, 2761) circumscribes the dog's body
#
# broadcasting
# Expanding the shape of an operand in a matrix math operation to dimensions compatible for that operation. For instance, linear algebra requires that the two operands in a matrix addition operation must have the same dimensions. Consequently, you can't add a matrix of shape (m, n) to a vector of length n. Broadcasting enables this operation by virtually expanding the vector of length n to a matrix of shape (m,n) by replicating the same values down each column.
#
# For example, given the following definitions, linear algebra prohibits A+B because A and B have different dimensions:
#
# A = [[7, 10, 4],
#      [13, 5, 9]]
# B = [2]
#
# However, broadcasting enables the operation A+B by virtually expanding B to:
#
#  [[2, 2, 2],
#   [2, 2, 2]]
#
# Thus, A+B is now a valid operation:
#
# [[7, 10, 4],  +  [[2, 2, 2],  =  [[ 9, 12, 6],
#  [13, 5, 9]]      [2, 2, 2]]      [15, 7, 11]]
#
# See the following description of broadcasting in NumPy for more details.
#
# bucketing
# Converting a (usually continuous) feature into multiple binary features called buckets or bins, typically based on value range. For example, instead of representing temperature as a single continuous floating-point feature, you could chop ranges of temperatures into discrete bins. Given temperature data sensitive to a tenth of a degree, all temperatures between 0.0 and 15.0 degrees could be put into one bin, 15.1 to 30.0 degrees could be a second bin, and 30.1 to 50.0 degrees could be a third bin.
#
# C
# calibration layer
# A post-prediction adjustment, typically to account for prediction bias. The adjusted predictions and probabilities should match the distribution of an observed set of labels.
#
# candidate generation
# The initial set of recommendations chosen by a recommendation system. For example, consider a bookstore that offers 100,000 titles. The candidate generation phase creates a much smaller list of suitable books for a particular user, say 500. But even 500 books is way too many to recommend to a user. Subsequent, more expensive, phases of a recommendation system (such as scoring and re-ranking) whittle down those 500 to a much smaller, more useful set of recommendations.
#
# candidate sampling
# A training-time optimization in which a probability is calculated for all the positive labels, using, for example, softmax, but only for a random sample of negative labels. For example, if we have an example labeled beagle and dog candidate sampling computes the predicted probabilities and corresponding loss terms for the beagle and dog class outputs in addition to a random subset of the remaining classes (cat, lollipop, fence). The idea is that the negative classes can learn from less frequent negative reinforcement as long as positive classes always get proper positive reinforcement, and this is indeed observed empirically. The motivation for candidate sampling is a computational efficiency win from not computing predictions for all negatives.
#
# categorical data
# Features having a discrete set of possible values. For example, consider a categorical feature named house style, which has a discrete set of three possible values: Tudor, ranch, colonial. By representing house style as categorical data, the model can learn the separate impacts of Tudor, ranch, and colonial on house price.
#
# Sometimes, values in the discrete set are mutually exclusive, and only one value can be applied to a given example. For example, a car maker categorical feature would probably permit only a single value (Toyota) per example. Other times, more than one value may be applicable. A single car could be painted more than one different color, so a car color categorical feature would likely permit a single example to have multiple values (for example, red and white).
#
# Categorical features are sometimes called discrete features.
#
# Contrast with numerical data.
#
# centroid
# The center of a cluster as determined by a k-means or k-median algorithm. For instance, if k is 3, then the k-means or k-median algorithm finds 3 centroids.
#
# centroid-based clustering
# A category of clustering algorithms that organizes data into nonhierarchical clusters. k-means is the most widely used centroid-based clustering algorithm.
#
# Contrast with hierarchical clustering algorithms.
#
# checkpoint
# Data that captures the state of the variables of a model at a particular time. Checkpoints enable exporting model weights, as well as performing training across multiple sessions. Checkpoints also enable training to continue past errors (for example, job preemption). Note that the graph itself is not included in a checkpoint.
#
# class
# One of a set of enumerated target values for a label. For example, in a binary classification model that detects spam, the two classes are spam and not spam. In a multi-class classification model that identifies dog breeds, the classes would be poodle, beagle, pug, and so on.
#
# classification model
# A type of machine learning model for distinguishing among two or more discrete classes. For example, a natural language processing classification model could determine whether an input sentence was in French, Spanish, or Italian. Compare with regression model.
#
# classification threshold
# A scalar-value criterion that is applied to a model's predicted score in order to separate the positive class from the negative class. Used when mapping logistic regression results to binary classification. For example, consider a logistic regression model that determines the probability of a given email message being spam. If the classification threshold is 0.9, then logistic regression values above 0.9 are classified as spam and those below 0.9 are classified as not spam.
#
# class-imbalanced dataset
# A binary classification problem in which the labels for the two classes have significantly different frequencies. For example, a disease dataset in which 0.0001 of examples have positive labels and 0.9999 have negative labels is a class-imbalanced problem, but a football game predictor in which 0.51 of examples label one team winning and 0.49 label the other team winning is not a class-imbalanced problem.
#
# clipping
# A technique for handling outliers. Specifically, reducing feature values that are greater than a set maximum value down to that maximum value. Also, increasing feature values that are less than a specific minimum value up to that minimum value.
#
# For example, suppose that only a few feature values fall outside the range 40–60. In this case, you could do the following:
#
# Clip all values over 60 to be exactly 60.
# Clip all values under 40 to be exactly 40.
# In addition to bringing input values within a designated range, clipping can also used to force gradient values within a designated range during training.
#
# Cloud TPU

# %%
doc=nlp(text)

# %%
for token in doc:
    print(token.text,'--',token.lemma_,'--', token.pos_,'--', token.tag_,'--', token.dep_,'--',
            token.shape_,'--', token.is_alpha,'--', token.is_stop)
# Out:
# A -- a -- DET -- DT -- det -- X -- True -- True
# / -- / -- SYM -- SYM -- punct -- / -- False -- False
# B -- b -- NOUN -- NN -- compound -- X -- True -- False
# testing -- testing -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# statistical -- statistical -- ADJ -- JJ -- amod -- xxxx -- True -- False
# way -- way -- NOUN -- NN -- npadvmod -- xxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# comparing -- compare -- VERB -- VBG -- pcomp -- xxxx -- True -- False
# two -- two -- NUM -- CD -- nummod -- xxx -- True -- True
# ( -- ( -- PUNCT -- -LRB- -- punct -- ( -- False -- False
# or -- or -- CCONJ -- CC -- cc -- xx -- True -- True
# more -- more -- ADJ -- JJR -- conj -- xxxx -- True -- True
# ) -- ) -- PUNCT -- -RRB- -- punct -- ) -- False -- False
# techniques -- technique -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# typically -- typically -- ADV -- RB -- advmod -- xxxx -- True -- False
# an -- an -- DET -- DT -- det -- xx -- True -- True
# incumbent -- incumbent -- NOUN -- NN -- appos -- xxxx -- True -- False
# against -- against -- ADP -- IN -- prep -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# new -- new -- ADJ -- JJ -- amod -- xxx -- True -- False
# rival -- rival -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# A -- a -- NOUN -- NN -- det -- X -- True -- True
# / -- / -- SYM -- SYM -- punct -- / -- False -- False
# B -- b -- NOUN -- NN -- compound -- X -- True -- False
# testing -- testing -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# aims -- aim -- VERB -- VBZ -- ROOT -- xxxx -- True -- False
# to -- to -- PART -- TO -- aux -- xx -- True -- True
# determine -- determine -- VERB -- VB -- xcomp -- xxxx -- True -- False
# not -- not -- PART -- RB -- preconj -- xxx -- True -- True
# only -- only -- ADV -- RB -- advmod -- xxxx -- True -- True
# which -- which -- DET -- WDT -- det -- xxxx -- True -- True
# technique -- technique -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# performs -- perform -- VERB -- VBZ -- ccomp -- xxxx -- True -- False
# better -- well -- ADJ -- JJR -- advmod -- xxxx -- True -- False
# but -- but -- CCONJ -- CC -- cc -- xxx -- True -- True
# also -- also -- ADV -- RB -- conj -- xxxx -- True -- True
# to -- to -- PART -- TO -- aux -- xx -- True -- True
# understand -- understand -- VERB -- VB -- xcomp -- xxxx -- True -- False
# whether -- whether -- SCONJ -- IN -- mark -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# difference -- difference -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- ccomp -- xx -- True -- True
# statistically -- statistically -- ADV -- RB -- advmod -- xxxx -- True -- False
# significant -- significant -- ADJ -- JJ -- acomp -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# A -- a -- NOUN -- NN -- det -- X -- True -- True
# / -- / -- SYM -- SYM -- punct -- / -- False -- False
# B -- b -- NOUN -- NN -- compound -- X -- True -- False
# testing -- testing -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# usually -- usually -- ADV -- RB -- advmod -- xxxx -- True -- False
# considers -- consider -- VERB -- VBZ -- ROOT -- xxxx -- True -- False
# only -- only -- ADV -- RB -- advmod -- xxxx -- True -- True
# two -- two -- NUM -- CD -- nummod -- xxx -- True -- True
# techniques -- technique -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# using -- use -- VERB -- VBG -- acl -- xxxx -- True -- True
# one -- one -- NUM -- CD -- nummod -- xxx -- True -- True
# measurement -- measurement -- NOUN -- NN -- dobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# but -- but -- CCONJ -- CC -- cc -- xxx -- True -- True
# it -- -PRON- -- PRON -- PRP -- nsubjpass -- xx -- True -- True
# can -- can -- VERB -- MD -- aux -- xxx -- True -- True
# be -- be -- AUX -- VB -- auxpass -- xx -- True -- True
# applied -- apply -- VERB -- VBN -- conj -- xxxx -- True -- False
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# any -- any -- DET -- DT -- det -- xxx -- True -- True
# finite -- finite -- ADJ -- JJ -- amod -- xxxx -- True -- False
# number -- number -- NOUN -- NN -- pobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# techniques -- technique -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# measures -- measure -- NOUN -- NNS -- conj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# accuracy -- accuracy -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# The -- the -- DET -- DT -- det -- Xxx -- True -- True
# fraction -- fraction -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# predictions -- prediction -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- mark -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# classification -- classification -- NOUN -- NN -- compound -- xxxx -- True -- False
# model -- model -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# got -- get -- VERB -- VBD -- relcl -- xxx -- True -- False
# right -- right -- ADJ -- JJ -- acomp -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# In -- in -- ADP -- IN -- prep -- Xx -- True -- True
# multi -- multi -- ADJ -- JJ -- dep -- xxxx -- True -- False
# - -- - -- ADJ -- JJ -- dep -- - -- False -- False
# class -- class -- ADJ -- JJ -- amod -- xxxx -- True -- False
# classification -- classification -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# accuracy -- accuracy -- NOUN -- NN -- nsubjpass -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- auxpass -- xx -- True -- True
# defined -- define -- VERB -- VBN -- ROOT -- xxxx -- True -- False
# as -- as -- SCONJ -- IN -- prep -- xx -- True -- True
# follows -- follow -- VERB -- VBZ -- pobj -- xxxx -- True -- False
# : -- : -- PUNCT -- : -- punct -- : -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# In -- in -- ADP -- IN -- prep -- Xx -- True -- True
# binary -- binary -- ADJ -- JJ -- amod -- xxxx -- True -- False
# classification -- classification -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# accuracy -- accuracy -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# has -- have -- AUX -- VBZ -- ROOT -- xxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# following -- follow -- VERB -- VBG -- amod -- xxxx -- True -- False
# definition -- definition -- NOUN -- NN -- dobj -- xxxx -- True -- False
# : -- : -- PUNCT -- : -- punct -- : -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# See -- see -- VERB -- VB -- acl -- Xxx -- True -- True
# true -- true -- ADJ -- JJ -- amod -- xxxx -- True -- False
# positive -- positive -- ADJ -- JJ -- amod -- xxxx -- True -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# true -- true -- ADJ -- JJ -- conj -- xxxx -- True -- False
# negative -- negative -- ADJ -- JJ -- acomp -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# action -- action -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# # -- # -- NOUN -- NN -- compound -- # -- False -- False
# rl -- rl -- VERB -- VBD -- ROOT -- xx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# In -- in -- ADP -- IN -- ROOT -- Xx -- True -- True
# reinforcement -- reinforcement -- NOUN -- NN -- compound -- xxxx -- True -- False
# learning -- learning -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# mechanism -- mechanism -- NOUN -- NN -- pobj -- xxxx -- True -- False
# by -- by -- ADP -- IN -- prep -- xx -- True -- True
# which -- which -- DET -- WDT -- pobj -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# agent -- agent -- NOUN -- NN -- compound -- xxxx -- True -- False
# transitions -- transition -- NOUN -- NNS -- relcl -- xxxx -- True -- False
# between -- between -- ADP -- IN -- prep -- xxxx -- True -- True
# states -- state -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# environment -- environment -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# The -- the -- DET -- DT -- det -- Xxx -- True -- True
# agent -- agent -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# chooses -- choose -- VERB -- VBZ -- ROOT -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# action -- action -- NOUN -- NN -- dobj -- xxxx -- True -- False
# by -- by -- ADP -- IN -- prep -- xx -- True -- True
# using -- use -- VERB -- VBG -- pcomp -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# policy -- policy -- NOUN -- NN -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# activation -- activation -- NOUN -- NN -- compound -- xxxx -- True -- False
# function -- function -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# function -- function -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# ( -- ( -- PUNCT -- -LRB- -- punct -- ( -- False -- False
# for -- for -- ADP -- IN -- intj -- xxx -- True -- True
# example -- example -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- intj -- , -- False -- False
# ReLU -- relu -- NOUN -- NN -- intj -- XxXX -- True -- False
# or -- or -- CCONJ -- CC -- cc -- xx -- True -- True
# sigmoid -- sigmoid -- NOUN -- NN -- conj -- xxxx -- True -- False
# ) -- ) -- PUNCT -- -RRB- -- punct -- ) -- False -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# takes -- take -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# in -- in -- ADP -- RP -- prt -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# weighted -- weighted -- ADJ -- JJ -- amod -- xxxx -- True -- False
# sum -- sum -- NOUN -- NN -- dobj -- xxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# all -- all -- DET -- DT -- pobj -- xxx -- True -- True
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# inputs -- input -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# from -- from -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# previous -- previous -- ADJ -- JJ -- amod -- xxxx -- True -- False
# layer -- layer -- NOUN -- NN -- pobj -- xxxx -- True -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# then -- then -- ADV -- RB -- advmod -- xxxx -- True -- True
# generates -- generate -- VERB -- VBZ -- conj -- xxxx -- True -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# passes -- pass -- VERB -- VBZ -- conj -- xxxx -- True -- False
# an -- an -- DET -- DT -- det -- xx -- True -- True
# output -- output -- NOUN -- NN -- compound -- xxxx -- True -- False
# value -- value -- NOUN -- NN -- dobj -- xxxx -- True -- False
# ( -- ( -- PUNCT -- -LRB- -- punct -- ( -- False -- False
# typically -- typically -- ADV -- RB -- advmod -- xxxx -- True -- False
# nonlinear -- nonlinear -- ADJ -- JJ -- amod -- xxxx -- True -- False
# ) -- ) -- PUNCT -- -RRB- -- punct -- ) -- False -- False
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# next -- next -- ADJ -- JJ -- amod -- xxxx -- True -- True
# layer -- layer -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# active -- active -- ADJ -- JJ -- amod -- xxxx -- True -- False
# learning -- learn -- VERB -- VBG -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# training -- training -- NOUN -- NN -- compound -- xxxx -- True -- False
# approach -- approach -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# which -- which -- DET -- WDT -- pobj -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# algorithm -- algorithm -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# chooses -- choose -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# some -- some -- DET -- DT -- dobj -- xxxx -- True -- True
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# data -- datum -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# it -- -PRON- -- PRON -- PRP -- nsubj -- xx -- True -- True
# learns -- learn -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# from -- from -- ADP -- IN -- prep -- xxxx -- True -- True
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# Active -- active -- ADJ -- JJ -- amod -- Xxxxx -- True -- False
# learning -- learning -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- ROOT -- xx -- True -- True
# particularly -- particularly -- ADV -- RB -- advmod -- xxxx -- True -- False
# valuable -- valuable -- ADJ -- JJ -- acomp -- xxxx -- True -- False
# when -- when -- ADV -- WRB -- advmod -- xxxx -- True -- True
# labeled -- label -- VERB -- VBN -- amod -- xxxx -- True -- False
# examples -- example -- NOUN -- NNS -- nsubj -- xxxx -- True -- False
# are -- be -- AUX -- VBP -- ccomp -- xxx -- True -- True
# scarce -- scarce -- ADJ -- JJ -- acomp -- xxxx -- True -- False
# or -- or -- CCONJ -- CC -- cc -- xx -- True -- True
# expensive -- expensive -- ADJ -- JJ -- conj -- xxxx -- True -- False
# to -- to -- PART -- TO -- aux -- xx -- True -- True
# obtain -- obtain -- VERB -- VB -- xcomp -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# Instead -- instead -- ADV -- RB -- advmod -- Xxxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# blindly -- blindly -- ADV -- RB -- advmod -- xxxx -- True -- False
# seeking -- seek -- VERB -- VBG -- pcomp -- xxxx -- True -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# diverse -- diverse -- ADJ -- JJ -- amod -- xxxx -- True -- False
# range -- range -- NOUN -- NN -- dobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# labeled -- label -- VERB -- VBN -- amod -- xxxx -- True -- False
# examples -- example -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# an -- an -- DET -- DT -- det -- xx -- True -- True
# active -- active -- ADJ -- JJ -- amod -- xxxx -- True -- False
# learning -- learn -- VERB -- VBG -- compound -- xxxx -- True -- False
# algorithm -- algorithm -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# selectively -- selectively -- ADV -- RB -- advmod -- xxxx -- True -- False
# seeks -- seek -- VERB -- VBZ -- ROOT -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# particular -- particular -- ADJ -- JJ -- amod -- xxxx -- True -- False
# range -- range -- NOUN -- NN -- dobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# examples -- example -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# it -- -PRON- -- PRON -- PRP -- nsubj -- xx -- True -- True
# needs -- need -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# learning -- learn -- VERB -- VBG -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# AdaGrad -- AdaGrad -- PROPN -- NNP -- ROOT -- XxxXxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# sophisticated -- sophisticated -- ADJ -- JJ -- amod -- xxxx -- True -- False
# gradient -- gradient -- NOUN -- NN -- compound -- xxxx -- True -- False
# descent -- descent -- NOUN -- NN -- compound -- xxxx -- True -- False
# algorithm -- algorithm -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# rescales -- rescale -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# gradients -- gradient -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# each -- each -- DET -- DT -- det -- xxxx -- True -- True
# parameter -- parameter -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# effectively -- effectively -- ADV -- RB -- advmod -- xxxx -- True -- False
# giving -- give -- VERB -- VBG -- advcl -- xxxx -- True -- False
# each -- each -- DET -- DT -- det -- xxxx -- True -- True
# parameter -- parameter -- NOUN -- NN -- dative -- xxxx -- True -- False
# an -- an -- DET -- DT -- det -- xx -- True -- True
# independent -- independent -- ADJ -- JJ -- amod -- xxxx -- True -- False
# learning -- learning -- NOUN -- NN -- compound -- xxxx -- True -- False
# rate -- rate -- NOUN -- NN -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# For -- for -- ADP -- IN -- prep -- Xxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# full -- full -- ADJ -- JJ -- amod -- xxxx -- True -- True
# explanation -- explanation -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# see -- see -- VERB -- VB -- ROOT -- xxx -- True -- True
# this -- this -- DET -- DT -- det -- xxxx -- True -- True
# paper -- paper -- NOUN -- NN -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# agent -- agent -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# # -- # -- PROPN -- NNP -- compound -- # -- False -- False
# rl -- rl -- VERB -- VBD -- ROOT -- xx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# In -- in -- ADP -- IN -- ROOT -- Xx -- True -- True
# reinforcement -- reinforcement -- NOUN -- NN -- compound -- xxxx -- True -- False
# learning -- learning -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# entity -- entity -- NOUN -- NN -- pobj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# uses -- use -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# policy -- policy -- NOUN -- NN -- dobj -- xxxx -- True -- False
# to -- to -- PART -- TO -- aux -- xx -- True -- True
# maximize -- maximize -- VERB -- VB -- xcomp -- xxxx -- True -- False
# expected -- expect -- VERB -- VBN -- amod -- xxxx -- True -- False
# return -- return -- NOUN -- NN -- dobj -- xxxx -- True -- False
# gained -- gain -- VERB -- VBN -- acl -- xxxx -- True -- False
# from -- from -- ADP -- IN -- prep -- xxxx -- True -- True
# transitioning -- transition -- VERB -- VBG -- pcomp -- xxxx -- True -- False
# between -- between -- ADP -- IN -- prep -- xxxx -- True -- True
# states -- state -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# environment -- environment -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# agglomerative -- agglomerative -- ADJ -- JJ -- amod -- xxxx -- True -- False
# clustering -- cluster -- VERB -- VBG -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# See -- see -- VERB -- VB -- ROOT -- Xxx -- True -- True
# hierarchical -- hierarchical -- ADJ -- JJ -- amod -- xxxx -- True -- False
# clustering -- clustering -- NOUN -- NN -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# AR -- AR -- PROPN -- NNP -- ROOT -- XX -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# Abbreviation -- Abbreviation -- PROPN -- NNP -- ROOT -- Xxxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# augmented -- augment -- VERB -- VBN -- amod -- xxxx -- True -- False
# reality -- reality -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# area -- area -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# under -- under -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# PR -- PR -- PROPN -- NNP -- compound -- XX -- True -- False
# curve -- curve -- NOUN -- NN -- pobj -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# See -- see -- NOUN -- NN -- ROOT -- Xxx -- True -- True
# PR -- PR -- PROPN -- NNP -- compound -- XX -- True -- False
# AUC -- AUC -- PROPN -- NNP -- dobj -- XXX -- True -- False
# ( -- ( -- PUNCT -- -LRB- -- punct -- ( -- False -- False
# Area -- area -- NOUN -- NN -- appos -- Xxxx -- True -- False
# under -- under -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# PR -- PR -- PROPN -- NNP -- compound -- XX -- True -- False
# Curve -- Curve -- PROPN -- NNP -- pobj -- Xxxxx -- True -- False
# ) -- ) -- PUNCT -- -RRB- -- punct -- ) -- False -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# area -- area -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# under -- under -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# ROC -- ROC -- PROPN -- NNP -- compound -- XXX -- True -- False
# curve -- curve -- NOUN -- NN -- pobj -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# See -- see -- VERB -- VB -- ROOT -- Xxx -- True -- True
# AUC -- AUC -- PROPN -- NNP -- dobj -- XXX -- True -- False
# ( -- ( -- PUNCT -- -LRB- -- punct -- ( -- False -- False
# Area -- area -- NOUN -- NN -- appos -- Xxxx -- True -- False
# under -- under -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# ROC -- ROC -- PROPN -- NNP -- compound -- XXX -- True -- False
# curve -- curve -- NOUN -- NN -- pobj -- xxxx -- True -- False
# ) -- ) -- PUNCT -- -RRB- -- punct -- ) -- False -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# artificial -- artificial -- ADJ -- JJ -- amod -- xxxx -- True -- False
# general -- general -- ADJ -- JJ -- amod -- xxxx -- True -- False
# intelligence -- intelligence -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# non -- non -- ADJ -- JJ -- dep -- xxx -- True -- False
# - -- - -- ADJ -- JJ -- dep -- - -- False -- False
# human -- human -- ADJ -- JJ -- amod -- xxxx -- True -- False
# mechanism -- mechanism -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# demonstrates -- demonstrate -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# broad -- broad -- ADJ -- JJ -- amod -- xxxx -- True -- False
# range -- range -- NOUN -- NN -- dobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# problem -- problem -- NOUN -- NN -- pobj -- xxxx -- True -- False
# solving -- solve -- VERB -- VBG -- acl -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# creativity -- creativity -- NOUN -- NN -- conj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# adaptability -- adaptability -- NOUN -- NN -- conj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# For -- for -- ADP -- IN -- prep -- Xxx -- True -- True
# example -- example -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# program -- program -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# demonstrating -- demonstrate -- VERB -- VBG -- acl -- xxxx -- True -- False
# artificial -- artificial -- ADJ -- JJ -- amod -- xxxx -- True -- False
# general -- general -- ADJ -- JJ -- amod -- xxxx -- True -- False
# intelligence -- intelligence -- NOUN -- NN -- dobj -- xxxx -- True -- False
# could -- could -- VERB -- MD -- aux -- xxxx -- True -- True
# translate -- translate -- VERB -- VB -- ROOT -- xxxx -- True -- False
# text -- text -- NOUN -- NN -- dobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# compose -- compose -- NOUN -- NN -- conj -- xxxx -- True -- False
# symphonies -- symphony -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# excel -- excel -- VERB -- VB -- conj -- xxxx -- True -- False
# at -- at -- ADP -- IN -- prep -- xx -- True -- True
# games -- game -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubjpass -- xxxx -- True -- True
# have -- have -- AUX -- VBP -- aux -- xxxx -- True -- True
# not -- not -- PART -- RB -- neg -- xxx -- True -- True
# yet -- yet -- ADV -- RB -- advmod -- xxx -- True -- True
# been -- be -- AUX -- VBN -- auxpass -- xxxx -- True -- True
# invented -- invent -- VERB -- VBN -- relcl -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# artificial -- artificial -- ADJ -- JJ -- amod -- xxxx -- True -- False
# intelligence -- intelligence -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# non -- non -- ADJ -- JJ -- dep -- xxx -- True -- False
# - -- - -- ADJ -- JJ -- dep -- - -- False -- False
# human -- human -- ADJ -- JJ -- amod -- xxxx -- True -- False
# program -- program -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# or -- or -- CCONJ -- CC -- cc -- xx -- True -- True
# model -- model -- NOUN -- NN -- conj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# can -- can -- VERB -- MD -- aux -- xxx -- True -- True
# solve -- solve -- VERB -- VB -- relcl -- xxxx -- True -- False
# sophisticated -- sophisticated -- ADJ -- JJ -- amod -- xxxx -- True -- False
# tasks -- task -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# For -- for -- ADP -- IN -- prep -- Xxx -- True -- True
# example -- example -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# program -- program -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# or -- or -- CCONJ -- CC -- cc -- xx -- True -- True
# model -- model -- NOUN -- NN -- conj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# translates -- translate -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# text -- text -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# or -- or -- CCONJ -- CC -- cc -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# program -- program -- NOUN -- NN -- conj -- xxxx -- True -- False
# or -- or -- CCONJ -- CC -- cc -- xx -- True -- True
# model -- model -- NOUN -- NN -- conj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# identifies -- identify -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# diseases -- disease -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# from -- from -- ADP -- IN -- prep -- xxxx -- True -- True
# radiologic -- radiologic -- ADJ -- JJ -- amod -- xxxx -- True -- False
# images -- image -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# both -- both -- CCONJ -- CC -- preconj -- xxxx -- True -- True
# exhibit -- exhibit -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# artificial -- artificial -- ADJ -- JJ -- amod -- xxxx -- True -- False
# intelligence -- intelligence -- NOUN -- NN -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# Formally -- formally -- ADV -- RB -- advmod -- Xxxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# machine -- machine -- NOUN -- NN -- compound -- xxxx -- True -- False
# learning -- learning -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- ROOT -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# sub -- sub -- ADJ -- JJ -- dep -- xxx -- True -- False
# - -- - -- ADJ -- JJ -- dep -- - -- False -- False
# field -- field -- NOUN -- NN -- attr -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# artificial -- artificial -- ADJ -- JJ -- amod -- xxxx -- True -- False
# intelligence -- intelligence -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# However -- however -- ADV -- RB -- advmod -- Xxxxx -- True -- True
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# recent -- recent -- ADJ -- JJ -- amod -- xxxx -- True -- False
# years -- year -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# some -- some -- DET -- DT -- det -- xxxx -- True -- True
# organizations -- organization -- NOUN -- NNS -- nsubj -- xxxx -- True -- False
# have -- have -- AUX -- VBP -- aux -- xxxx -- True -- True
# begun -- begin -- VERB -- VBN -- ROOT -- xxxx -- True -- False
# using -- use -- VERB -- VBG -- xcomp -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# terms -- term -- NOUN -- NNS -- dative -- xxxx -- True -- False
# artificial -- artificial -- ADJ -- JJ -- amod -- xxxx -- True -- False
# intelligence -- intelligence -- NOUN -- NN -- nmod -- xxxx -- True -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# machine -- machine -- NOUN -- NN -- conj -- xxxx -- True -- False
# learning -- learn -- VERB -- VBG -- xcomp -- xxxx -- True -- False
# interchangeably -- interchangeably -- ADV -- RB -- advmod -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# attribute -- attribute -- VERB -- VB -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# # -- # -- PROPN -- NNP -- nmod -- # -- False -- False
# fairness -- fairness -- NOUN -- NN -- dobj -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# Synonym -- synonym -- NOUN -- NN -- appos -- Xxxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# feature -- feature -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# In -- in -- ADP -- IN -- prep -- Xx -- True -- True
# fairness -- fairness -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# attributes -- attribute -- NOUN -- NNS -- nsubj -- xxxx -- True -- False
# often -- often -- ADV -- RB -- advmod -- xxxx -- True -- True
# refer -- refer -- VERB -- VBP -- ROOT -- xxxx -- True -- False
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# characteristics -- characteristic -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# pertaining -- pertain -- VERB -- VBG -- advcl -- xxxx -- True -- False
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# individuals -- individual -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# AUC -- AUC -- PROPN -- NNP -- ROOT -- XXX -- True -- False
# ( -- ( -- PUNCT -- -LRB- -- punct -- ( -- False -- False
# Area -- area -- NOUN -- NN -- appos -- Xxxx -- True -- False
# under -- under -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# ROC -- ROC -- PROPN -- NNP -- compound -- XXX -- True -- False
# Curve -- Curve -- PROPN -- NNP -- pobj -- Xxxxx -- True -- False
# ) -- ) -- PUNCT -- -RRB- -- punct -- ) -- False -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# An -- an -- DET -- DT -- det -- Xx -- True -- True
# evaluation -- evaluation -- NOUN -- NN -- compound -- xxxx -- True -- False
# metric -- metric -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# considers -- consider -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# all -- all -- DET -- DT -- det -- xxx -- True -- True
# possible -- possible -- ADJ -- JJ -- amod -- xxxx -- True -- False
# classification -- classification -- NOUN -- NN -- compound -- xxxx -- True -- False
# thresholds -- threshold -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# The -- the -- DET -- DT -- det -- Xxx -- True -- True
# Area -- area -- NOUN -- NN -- nsubj -- Xxxx -- True -- False
# Under -- under -- ADP -- IN -- prep -- Xxxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# ROC -- ROC -- PROPN -- NNP -- compound -- XXX -- True -- False
# curve -- curve -- NOUN -- NN -- pobj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- ROOT -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# probability -- probability -- NOUN -- NN -- attr -- xxxx -- True -- False
# that -- that -- SCONJ -- IN -- mark -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# classifier -- classifier -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# will -- will -- VERB -- MD -- aux -- xxxx -- True -- True
# be -- be -- AUX -- VB -- acl -- xx -- True -- True
# more -- more -- ADV -- RBR -- advmod -- xxxx -- True -- True
# confident -- confident -- ADJ -- JJ -- acomp -- xxxx -- True -- False
# that -- that -- SCONJ -- IN -- mark -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# randomly -- randomly -- ADV -- RB -- advmod -- xxxx -- True -- False
# chosen -- choose -- VERB -- VBN -- amod -- xxxx -- True -- False
# positive -- positive -- ADJ -- JJ -- amod -- xxxx -- True -- False
# example -- example -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- ccomp -- xx -- True -- True
# actually -- actually -- ADV -- RB -- advmod -- xxxx -- True -- False
# positive -- positive -- ADJ -- JJ -- acomp -- xxxx -- True -- False
# than -- than -- SCONJ -- IN -- mark -- xxxx -- True -- True
# that -- that -- DET -- DT -- mark -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# randomly -- randomly -- ADV -- RB -- advmod -- xxxx -- True -- False
# chosen -- choose -- VERB -- VBN -- amod -- xxxx -- True -- False
# negative -- negative -- ADJ -- JJ -- amod -- xxxx -- True -- False
# example -- example -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- advcl -- xx -- True -- True
# positive -- positive -- ADJ -- JJ -- acomp -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# augmented -- augment -- VERB -- VBD -- ROOT -- xxxx -- True -- False
# reality -- reality -- NOUN -- NN -- dobj -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# technology -- technology -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# superimposes -- superimpose -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# computer -- computer -- NOUN -- NN -- npadvmod -- xxxx -- True -- False
# - -- - -- PUNCT -- HYPH -- punct -- - -- False -- False
# generated -- generate -- VERB -- VBN -- amod -- xxxx -- True -- False
# image -- image -- NOUN -- NN -- dobj -- xxxx -- True -- False
# on -- on -- ADP -- IN -- prep -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# user -- user -- NOUN -- NN -- poss -- xxxx -- True -- False
# 's -- 's -- PART -- POS -- case -- 'x -- False -- True
# view -- view -- NOUN -- NN -- pobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# real -- real -- ADJ -- JJ -- amod -- xxxx -- True -- False
# world -- world -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# thus -- thus -- ADV -- RB -- advmod -- xxxx -- True -- True
# providing -- provide -- VERB -- VBG -- advcl -- xxxx -- True -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# composite -- composite -- ADJ -- JJ -- amod -- xxxx -- True -- False
# view -- view -- NOUN -- NN -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# automation -- automation -- NOUN -- NN -- compound -- xxxx -- True -- False
# bias -- bias -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# # -- # -- NOUN -- NN -- nmod -- # -- False -- False
# fairness -- fairness -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# When -- when -- ADV -- WRB -- advmod -- Xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# human -- human -- ADJ -- JJ -- amod -- xxxx -- True -- False
# decision -- decision -- NOUN -- NN -- compound -- xxxx -- True -- False
# maker -- maker -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# favors -- favor -- VERB -- VBZ -- ROOT -- xxxx -- True -- False
# recommendations -- recommendation -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# made -- make -- VERB -- VBN -- acl -- xxxx -- True -- True
# by -- by -- ADP -- IN -- agent -- xx -- True -- True
# an -- an -- DET -- DT -- det -- xx -- True -- True
# automated -- automate -- VERB -- VBN -- amod -- xxxx -- True -- False
# decision -- decision -- NOUN -- NN -- npadvmod -- xxxx -- True -- False
# - -- - -- PUNCT -- HYPH -- punct -- - -- False -- False
# making -- make -- VERB -- VBG -- amod -- xxxx -- True -- False
# system -- system -- NOUN -- NN -- pobj -- xxxx -- True -- False
# over -- over -- ADP -- IN -- prep -- xxxx -- True -- True
# information -- information -- NOUN -- NN -- pobj -- xxxx -- True -- False
# made -- make -- VERB -- VBN -- acl -- xxxx -- True -- True
# without -- without -- ADP -- IN -- prep -- xxxx -- True -- True
# automation -- automation -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# even -- even -- ADV -- RB -- advmod -- xxxx -- True -- True
# when -- when -- ADV -- WRB -- advmod -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# automated -- automate -- VERB -- VBN -- amod -- xxxx -- True -- False
# decision -- decision -- NOUN -- NN -- npadvmod -- xxxx -- True -- False
# - -- - -- PUNCT -- HYPH -- punct -- - -- False -- False
# making -- make -- VERB -- VBG -- amod -- xxxx -- True -- False
# system -- system -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# makes -- make -- VERB -- VBZ -- advcl -- xxxx -- True -- False
# errors -- error -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# average -- average -- ADJ -- JJ -- amod -- xxxx -- True -- False
# precision -- precision -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# metric -- metric -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# summarizing -- summarize -- VERB -- VBG -- pcomp -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# performance -- performance -- NOUN -- NN -- dobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# ranked -- rank -- VERB -- VBN -- amod -- xxxx -- True -- False
# sequence -- sequence -- NOUN -- NN -- pobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# results -- result -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# Average -- average -- ADJ -- JJ -- amod -- Xxxxx -- True -- False
# precision -- precision -- NOUN -- NN -- nsubjpass -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- auxpass -- xx -- True -- True
# calculated -- calculate -- VERB -- VBN -- ROOT -- xxxx -- True -- False
# by -- by -- ADP -- IN -- prep -- xx -- True -- True
# taking -- take -- VERB -- VBG -- pcomp -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# average -- average -- NOUN -- NN -- dobj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# precision -- precision -- NOUN -- NN -- compound -- xxxx -- True -- False
# values -- value -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# each -- each -- DET -- DT -- det -- xxxx -- True -- True
# relevant -- relevant -- ADJ -- JJ -- amod -- xxxx -- True -- False
# result -- result -- NOUN -- NN -- pobj -- xxxx -- True -- False
# ( -- ( -- PUNCT -- -LRB- -- punct -- ( -- False -- False
# each -- each -- DET -- DT -- det -- xxxx -- True -- True
# result -- result -- NOUN -- NN -- parataxis -- xxxx -- True -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# ranked -- ranked -- ADJ -- JJ -- amod -- xxxx -- True -- False
# list -- list -- NOUN -- NN -- pobj -- xxxx -- True -- False
# where -- where -- ADV -- WRB -- advmod -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# recall -- recall -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# increases -- increase -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# relative -- relative -- ADJ -- JJ -- advmod -- xxxx -- True -- False
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# previous -- previous -- ADJ -- JJ -- amod -- xxxx -- True -- False
# result -- result -- NOUN -- NN -- pobj -- xxxx -- True -- False
# ) -- ) -- PUNCT -- -RRB- -- punct -- ) -- False -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# See -- see -- VERB -- VB -- ROOT -- Xxx -- True -- True
# also -- also -- ADV -- RB -- advmod -- xxxx -- True -- True
# Area -- Area -- PROPN -- NNP -- dobj -- Xxxx -- True -- False
# under -- under -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# PR -- PR -- PROPN -- NNP -- compound -- XX -- True -- False
# Curve -- Curve -- PROPN -- NNP -- pobj -- Xxxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# B -- b -- NOUN -- NN -- ROOT -- X -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# backpropagation -- backpropagation -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# The -- the -- DET -- DT -- det -- Xxx -- True -- True
# primary -- primary -- ADJ -- JJ -- amod -- xxxx -- True -- False
# algorithm -- algorithm -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# performing -- perform -- VERB -- VBG -- pcomp -- xxxx -- True -- False
# gradient -- gradient -- NOUN -- NN -- amod -- xxxx -- True -- False
# descent -- descent -- NOUN -- NN -- dobj -- xxxx -- True -- False
# on -- on -- ADP -- IN -- prep -- xx -- True -- True
# neural -- neural -- ADJ -- JJ -- amod -- xxxx -- True -- False
# networks -- network -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# First -- first -- ADV -- RB -- advmod -- Xxxxx -- True -- True
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# output -- output -- NOUN -- NN -- compound -- xxxx -- True -- False
# values -- value -- NOUN -- NNS -- nsubjpass -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# each -- each -- DET -- DT -- det -- xxxx -- True -- True
# node -- node -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# are -- be -- AUX -- VBP -- auxpass -- xxx -- True -- True
# calculated -- calculate -- VERB -- VBN -- ROOT -- xxxx -- True -- False
# ( -- ( -- PUNCT -- -LRB- -- punct -- ( -- False -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# cached -- cache -- VERB -- VBD -- conj -- xxxx -- True -- False
# ) -- ) -- PUNCT -- -RRB- -- punct -- ) -- False -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# forward -- forward -- ADJ -- JJ -- amod -- xxxx -- True -- False
# pass -- pass -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# Then -- then -- ADV -- RB -- advmod -- Xxxx -- True -- True
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# partial -- partial -- ADJ -- JJ -- amod -- xxxx -- True -- False
# derivative -- derivative -- NOUN -- NN -- nsubjpass -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# error -- error -- NOUN -- NN -- pobj -- xxxx -- True -- False
# with -- with -- ADP -- IN -- prep -- xxxx -- True -- True
# respect -- respect -- NOUN -- NN -- pobj -- xxxx -- True -- False
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# each -- each -- DET -- DT -- det -- xxxx -- True -- True
# parameter -- parameter -- NOUN -- NN -- pobj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- auxpass -- xx -- True -- True
# calculated -- calculate -- VERB -- VBN -- ROOT -- xxxx -- True -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# backward -- backward -- ADJ -- JJ -- amod -- xxxx -- True -- False
# pass -- pass -- NOUN -- NN -- pobj -- xxxx -- True -- False
# through -- through -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# graph -- graph -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# bag -- bag -- NOUN -- NN -- ROOT -- xxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# words -- word -- NOUN -- NNS -- pobj -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# representation -- representation -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# words -- word -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# phrase -- phrase -- NOUN -- NN -- pobj -- xxxx -- True -- False
# or -- or -- CCONJ -- CC -- cc -- xx -- True -- True
# passage -- passage -- NOUN -- NN -- conj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# irrespective -- irrespective -- ADV -- RB -- amod -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# order -- order -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# For -- for -- ADP -- IN -- prep -- Xxx -- True -- True
# example -- example -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# bag -- bag -- NOUN -- NN -- nsubj -- xxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# words -- word -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# represents -- represent -- VERB -- VBZ -- ROOT -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# ...
# from -- from -- ADP -- IN -- prep -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# negative -- negative -- ADJ -- JJ -- amod -- xxxx -- True -- False
# class -- class -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# Used -- use -- VERB -- VBN -- ROOT -- Xxxx -- True -- True
# when -- when -- ADV -- WRB -- advmod -- xxxx -- True -- True
# mapping -- map -- VERB -- VBG -- advcl -- xxxx -- True -- False
# logistic -- logistic -- ADJ -- JJ -- amod -- xxxx -- True -- False
# regression -- regression -- NOUN -- NN -- dobj -- xxxx -- True -- False
# results -- result -- NOUN -- NNS -- ccomp -- xxxx -- True -- False
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# binary -- binary -- ADJ -- JJ -- amod -- xxxx -- True -- False
# classification -- classification -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# For -- for -- ADP -- IN -- prep -- Xxx -- True -- True
# example -- example -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# consider -- consider -- VERB -- VB -- ROOT -- xxxx -- True -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# logistic -- logistic -- ADJ -- JJ -- amod -- xxxx -- True -- False
# regression -- regression -- NOUN -- NN -- compound -- xxxx -- True -- False
# model -- model -- NOUN -- NN -- dobj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# determines -- determine -- VERB -- VBZ -- relcl -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# probability -- probability -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# given -- give -- VERB -- VBN -- amod -- xxxx -- True -- False
# email -- email -- NOUN -- NN -- compound -- xxxx -- True -- False
# message -- message -- NOUN -- NN -- pobj -- xxxx -- True -- False
# being -- be -- AUX -- VBG -- ccomp -- xxxx -- True -- True
# spam -- spam -- NOUN -- NN -- acomp -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# If -- if -- SCONJ -- IN -- mark -- Xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# classification -- classification -- NOUN -- NN -- compound -- xxxx -- True -- False
# threshold -- threshold -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- advcl -- xx -- True -- True
# 0.9 -- 0.9 -- NUM -- CD -- attr -- d.d -- False -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# then -- then -- ADV -- RB -- advmod -- xxxx -- True -- True
# logistic -- logistic -- ADJ -- JJ -- amod -- xxxx -- True -- False
# regression -- regression -- NOUN -- NN -- compound -- xxxx -- True -- False
# values -- value -- NOUN -- NNS -- nsubjpass -- xxxx -- True -- False
# above -- above -- ADP -- IN -- prep -- xxxx -- True -- True
# 0.9 -- 0.9 -- NUM -- CD -- pobj -- d.d -- False -- False
# are -- be -- AUX -- VBP -- auxpass -- xxx -- True -- True
# classified -- classify -- VERB -- VBN -- ROOT -- xxxx -- True -- False
# as -- as -- SCONJ -- IN -- prep -- xx -- True -- True
# spam -- spam -- NOUN -- NN -- pobj -- xxxx -- True -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# those -- those -- DET -- DT -- nsubjpass -- xxxx -- True -- True
# below -- below -- ADP -- IN -- prep -- xxxx -- True -- True
# 0.9 -- 0.9 -- NUM -- CD -- pobj -- d.d -- False -- False
# are -- be -- AUX -- VBP -- auxpass -- xxx -- True -- True
# classified -- classify -- VERB -- VBN -- conj -- xxxx -- True -- False
# as -- as -- SCONJ -- IN -- prep -- xx -- True -- True
# not -- not -- PART -- RB -- neg -- xxx -- True -- True
# spam -- spam -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# class -- class -- NOUN -- NN -- npadvmod -- xxxx -- True -- False
# - -- - -- PUNCT -- HYPH -- punct -- - -- False -- False
# imbalanced -- imbalanced -- ADJ -- JJ -- amod -- xxxx -- True -- False
# dataset -- dataset -- NOUN -- NN -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# binary -- binary -- ADJ -- JJ -- amod -- xxxx -- True -- False
# classification -- classification -- NOUN -- NN -- compound -- xxxx -- True -- False
# problem -- problem -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# which -- which -- DET -- WDT -- pobj -- xxxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# labels -- label -- NOUN -- NNS -- nsubj -- xxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# two -- two -- NUM -- CD -- nummod -- xxx -- True -- True
# classes -- class -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# have -- have -- AUX -- VBP -- relcl -- xxxx -- True -- True
# significantly -- significantly -- ADV -- RB -- advmod -- xxxx -- True -- False
# different -- different -- ADJ -- JJ -- amod -- xxxx -- True -- False
# frequencies -- frequency -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# For -- for -- ADP -- IN -- prep -- Xxx -- True -- True
# example -- example -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# a -- a -- DET -- DT -- det -- x -- True -- True
# disease -- disease -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# dataset -- dataset -- VERB -- VBN -- ROOT -- xxxx -- True -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# which -- which -- DET -- WDT -- pobj -- xxxx -- True -- True
# 0.0001 -- 0.0001 -- NUM -- CD -- nsubj -- d.dddd -- False -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# examples -- example -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# have -- have -- AUX -- VBP -- advcl -- xxxx -- True -- True
# positive -- positive -- ADJ -- JJ -- amod -- xxxx -- True -- False
# labels -- label -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# 0.9999 -- 0.9999 -- NUM -- CD -- conj -- d.dddd -- False -- False
# have -- have -- AUX -- VBP -- ROOT -- xxxx -- True -- True
# negative -- negative -- ADJ -- JJ -- amod -- xxxx -- True -- False
# labels -- label -- NOUN -- NNS -- nsubj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- ccomp -- xx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# class -- class -- NOUN -- NN -- npadvmod -- xxxx -- True -- False
# - -- - -- PUNCT -- HYPH -- punct -- - -- False -- False
# imbalanced -- imbalanced -- ADJ -- JJ -- amod -- xxxx -- True -- False
# problem -- problem -- NOUN -- NN -- attr -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# but -- but -- CCONJ -- CC -- cc -- xxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# football -- football -- NOUN -- NN -- compound -- xxxx -- True -- False
# game -- game -- NOUN -- NN -- compound -- xxxx -- True -- False
# predictor -- predictor -- NOUN -- NN -- conj -- xxxx -- True -- False
# in -- in -- ADP -- IN -- prep -- xx -- True -- True
# which -- which -- DET -- WDT -- pobj -- xxxx -- True -- True
# 0.51 -- 0.51 -- NUM -- CD -- nsubj -- d.dd -- False -- False
# of -- of -- ADP -- IN -- prep -- xx -- True -- True
# examples -- example -- NOUN -- NNS -- pobj -- xxxx -- True -- False
# label -- label -- VERB -- VBP -- relcl -- xxxx -- True -- False
# one -- one -- NUM -- CD -- nummod -- xxx -- True -- True
# team -- team -- NOUN -- NN -- dobj -- xxxx -- True -- False
# winning -- win -- VERB -- VBG -- acl -- xxxx -- True -- False
# and -- and -- CCONJ -- CC -- cc -- xxx -- True -- True
# 0.49 -- 0.49 -- PROPN -- NNP -- nummod -- d.dd -- False -- False
# label -- label -- VERB -- VB -- conj -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# other -- other -- ADJ -- JJ -- amod -- xxxx -- True -- True
# team -- team -- NOUN -- NN -- nsubj -- xxxx -- True -- False
# winning -- win -- VERB -- VBG -- csubj -- xxxx -- True -- False
# is -- be -- AUX -- VBZ -- ROOT -- xx -- True -- True
# not -- not -- PART -- RB -- neg -- xxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# class -- class -- NOUN -- NN -- npadvmod -- xxxx -- True -- False
# - -- - -- PUNCT -- HYPH -- punct -- - -- False -- False
# imbalanced -- imbalanced -- ADJ -- JJ -- amod -- xxxx -- True -- False
# problem -- problem -- NOUN -- NN -- attr -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# clipping -- clip -- VERB -- VBG -- ROOT -- xxxx -- True -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# A -- a -- DET -- DT -- det -- X -- True -- True
# technique -- technique -- NOUN -- NN -- ROOT -- xxxx -- True -- False
# for -- for -- ADP -- IN -- prep -- xxx -- True -- True
# handling -- handle -- VERB -- VBG -- pcomp -- xxxx -- True -- False
# outliers -- outlier -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# Specifically -- specifically -- ADV -- RB -- ROOT -- Xxxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# reducing -- reduce -- VERB -- VBG -- intj -- xxxx -- True -- False
# feature -- feature -- NOUN -- NN -- compound -- xxxx -- True -- False
# values -- value -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# are -- be -- AUX -- VBP -- relcl -- xxx -- True -- True
# greater -- great -- ADJ -- JJR -- acomp -- xxxx -- True -- False
# than -- than -- SCONJ -- IN -- prep -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# set -- set -- VERB -- VBN -- amod -- xxx -- True -- False
# maximum -- maximum -- NOUN -- NN -- amod -- xxxx -- True -- False
# value -- value -- NOUN -- NN -- pobj -- xxxx -- True -- False
# down -- down -- ADV -- RB -- advmod -- xxxx -- True -- True
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# that -- that -- DET -- DT -- det -- xxxx -- True -- True
# maximum -- maximum -- ADJ -- JJ -- amod -- xxxx -- True -- False
# value -- value -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# Also -- also -- ADV -- RB -- ROOT -- Xxxx -- True -- True
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# increasing -- increase -- VERB -- VBG -- intj -- xxxx -- True -- False
# feature -- feature -- NOUN -- NN -- compound -- xxxx -- True -- False
# values -- value -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# that -- that -- DET -- WDT -- nsubj -- xxxx -- True -- True
# are -- be -- AUX -- VBP -- relcl -- xxx -- True -- True
# less -- less -- ADJ -- JJR -- acomp -- xxxx -- True -- True
# than -- than -- SCONJ -- IN -- prep -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# specific -- specific -- ADJ -- JJ -- amod -- xxxx -- True -- False
# minimum -- minimum -- NOUN -- NN -- amod -- xxxx -- True -- False
# value -- value -- NOUN -- NN -- pobj -- xxxx -- True -- False
# up -- up -- ADP -- IN -- prep -- xx -- True -- True
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# that -- that -- DET -- DT -- det -- xxxx -- True -- True
# minimum -- minimum -- ADJ -- JJ -- amod -- xxxx -- True -- False
# value -- value -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# For -- for -- ADP -- IN -- prep -- Xxx -- True -- True
# example -- example -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# suppose -- suppose -- VERB -- VBP -- ROOT -- xxxx -- True -- False
# that -- that -- SCONJ -- IN -- mark -- xxxx -- True -- True
# only -- only -- ADV -- RB -- advmod -- xxxx -- True -- True
# a -- a -- DET -- DT -- quantmod -- x -- True -- True
# few -- few -- ADJ -- JJ -- nummod -- xxx -- True -- True
# feature -- feature -- NOUN -- NN -- compound -- xxxx -- True -- False
# values -- value -- NOUN -- NNS -- nsubj -- xxxx -- True -- False
# fall -- fall -- VERB -- VBP -- ccomp -- xxxx -- True -- False
# outside -- outside -- ADP -- IN -- prep -- xxxx -- True -- False
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# range -- range -- NOUN -- NN -- compound -- xxxx -- True -- False
# 40–60 -- 40–60 -- NOUN -- NN -- pobj -- dd–dd -- False -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
# In -- in -- ADP -- IN -- prep -- Xx -- True -- True
# this -- this -- DET -- DT -- det -- xxxx -- True -- True
# case -- case -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# you -- -PRON- -- PRON -- PRP -- nsubj -- xxx -- True -- True
# could -- could -- VERB -- MD -- aux -- xxxx -- True -- True
# do -- do -- AUX -- VB -- ROOT -- xx -- True -- True
# the -- the -- DET -- DT -- det -- xxx -- True -- True
# following -- follow -- VERB -- VBG -- dobj -- xxxx -- True -- False
# : -- : -- PUNCT -- : -- punct -- : -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# Clip -- clip -- VERB -- VB -- acl -- Xxxx -- True -- False
# all -- all -- DET -- DT -- det -- xxx -- True -- True
# values -- value -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# over -- over -- ADP -- IN -- prep -- xxxx -- True -- True
# 60 -- 60 -- NUM -- CD -- pobj -- dd -- False -- False
# to -- to -- PART -- TO -- aux -- xx -- True -- True
# be -- be -- AUX -- VB -- advcl -- xx -- True -- True
# exactly -- exactly -- ADV -- RB -- advmod -- xxxx -- True -- False
# 60 -- 60 -- NUM -- CD -- attr -- dd -- False -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# Clip -- clip -- VERB -- VB -- ROOT -- Xxxx -- True -- False
# all -- all -- DET -- DT -- det -- xxx -- True -- True
# values -- value -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# under -- under -- ADP -- IN -- prep -- xxxx -- True -- True
# 40 -- 40 -- NUM -- CD -- pobj -- dd -- False -- False
# to -- to -- PART -- TO -- aux -- xx -- True -- True
# be -- be -- AUX -- VB -- advcl -- xx -- True -- True
# exactly -- exactly -- ADV -- RB -- advmod -- xxxx -- True -- False
# 40 -- 40 -- NUM -- CD -- attr -- dd -- False -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#  --
#  -- SPACE -- _SP --  --
#  -- False -- False
# In -- in -- ADP -- IN -- prep -- Xx -- True -- True
# addition -- addition -- NOUN -- NN -- pobj -- xxxx -- True -- False
# to -- to -- ADP -- IN -- prep -- xx -- True -- True
# bringing -- bring -- VERB -- VBG -- pcomp -- xxxx -- True -- False
# input -- input -- NOUN -- NN -- compound -- xxxx -- True -- False
# values -- value -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# within -- within -- ADP -- IN -- prep -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# designated -- designate -- VERB -- VBN -- amod -- xxxx -- True -- False
# range -- range -- NOUN -- NN -- pobj -- xxxx -- True -- False
# , -- , -- PUNCT -- , -- punct -- , -- False -- False
# clipping -- clip -- VERB -- VBG -- nsubj -- xxxx -- True -- False
# can -- can -- VERB -- MD -- aux -- xxx -- True -- True
# also -- also -- ADV -- RB -- advmod -- xxxx -- True -- True
# used -- use -- VERB -- VBN -- ROOT -- xxxx -- True -- True
# to -- to -- PART -- TO -- aux -- xx -- True -- True
# force -- force -- VERB -- VB -- xcomp -- xxxx -- True -- False
# gradient -- gradient -- ADJ -- JJ -- compound -- xxxx -- True -- False
# values -- value -- NOUN -- NNS -- dobj -- xxxx -- True -- False
# within -- within -- ADP -- IN -- prep -- xxxx -- True -- True
# a -- a -- DET -- DT -- det -- x -- True -- True
# designated -- designate -- VERB -- VBN -- amod -- xxxx -- True -- False
# range -- range -- NOUN -- NN -- pobj -- xxxx -- True -- False
# during -- during -- ADP -- IN -- prep -- xxxx -- True -- True
# training -- training -- NOUN -- NN -- pobj -- xxxx -- True -- False
# . -- . -- PUNCT -- . -- punct -- . -- False -- False
#
#
#  --
#
#  -- SPACE -- _SP --  --
#
#  -- False -- False
# Cloud -- cloud -- NOUN -- NN -- compound -- Xxxxx -- True -- False
# TPU -- tpu -- NOUN -- NN -- ROOT -- XXX -- True -- False

# %%
for chunk in doc.noun_chunks:
    print(chunk.text,'--', chunk.root.text,'--', chunk.root.dep_,'--',
            chunk.root.head.text)
# Out:
# A/B testing -- testing -- ROOT -- testing
# two (or more) techniques -- techniques -- dobj -- comparing
# typically an incumbent -- incumbent -- appos -- techniques
# a new rival -- rival -- pobj -- against
# A/B testing -- testing -- nsubj -- aims
# not only which technique -- technique -- nsubj -- performs
# the difference -- difference -- nsubj -- is
# A/B testing -- testing -- nsubj -- considers
# only two techniques -- techniques -- dobj -- considers
# one measurement -- measurement -- dobj -- using
# it -- it -- nsubjpass -- applied
# any finite number -- number -- pobj -- to
# techniques -- techniques -- pobj -- of
# measures -- measures -- conj -- techniques
# accuracy -- accuracy -- ROOT -- accuracy
# The fraction -- fraction -- ROOT -- fraction
# predictions -- predictions -- pobj -- of
# a classification model -- model -- nsubj -- got
# multi-class classification -- classification -- pobj -- In
# accuracy -- accuracy -- nsubjpass -- defined
# binary classification -- classification -- pobj -- In
# accuracy -- accuracy -- nsubj -- has
# the following definition -- definition -- dobj -- has
# action -- action -- ROOT -- action
# reinforcement learning -- learning -- pobj -- In
# the mechanism -- mechanism -- pobj -- In
# states -- states -- pobj -- between
# the environment -- environment -- pobj -- of
# The agent -- agent -- nsubj -- chooses
# the action -- action -- dobj -- chooses
# a policy -- policy -- dobj -- using
# activation function -- function -- ROOT -- function
# A function -- function -- ROOT -- function
# example -- example -- pobj -- for
# the weighted sum -- sum -- dobj -- takes
# the inputs -- inputs -- pobj -- of
# the previous layer -- layer -- pobj -- from
# an output value -- value -- dobj -- passes
# the next layer -- layer -- pobj -- to
# A training approach -- approach -- ROOT -- approach
# the algorithm -- algorithm -- nsubj -- chooses
# the data -- data -- pobj -- of
# it -- it -- nsubj -- learns
# Active learning -- learning -- nsubj -- is
# when labeled examples -- examples -- nsubj -- are
# a diverse range -- range -- dobj -- seeking
# labeled examples -- examples -- pobj -- of
# an active learning algorithm -- algorithm -- nsubj -- seeks
# the particular range -- range -- dobj -- seeks
# examples -- examples -- pobj -- of
# it -- it -- nsubj -- needs
# AdaGrad -- AdaGrad -- ROOT -- AdaGrad
# A sophisticated gradient descent algorithm -- algorithm -- ROOT -- algorithm
# the gradients -- gradients -- dobj -- rescales
# each parameter -- parameter -- pobj -- of
# each parameter -- parameter -- dative -- giving
# an independent learning rate -- rate -- dobj -- giving
# a full explanation -- explanation -- pobj -- For
# this paper -- paper -- dobj -- see
# agent -- agent -- ROOT -- agent
# reinforcement learning -- learning -- pobj -- In
# the entity -- entity -- pobj -- In
# a policy -- policy -- dobj -- uses
# expected return -- return -- dobj -- maximize
# states -- states -- pobj -- between
# the environment -- environment -- pobj -- of
# hierarchical clustering -- clustering -- dobj -- See
# AR -- AR -- ROOT -- AR
# Abbreviation -- Abbreviation -- ROOT -- Abbreviation
# augmented reality -- reality -- pobj -- for
# area -- area -- nsubj -- See
# the PR curve -- curve -- pobj -- under
# PR AUC -- AUC -- dobj -- See
# Area -- Area -- appos -- AUC
# the PR Curve -- Curve -- pobj -- under
# area -- area -- nsubj -- See
# the ROC curve -- curve -- pobj -- under
# AUC -- AUC -- dobj -- See
# Area -- Area -- appos -- AUC
# the ROC curve -- curve -- pobj -- under
# artificial general intelligence -- intelligence -- ROOT -- intelligence
# A non-human mechanism -- mechanism -- ROOT -- mechanism
# a broad range -- range -- dobj -- demonstrates
# problem -- problem -- pobj -- of
# example -- example -- pobj -- For
# a program -- program -- nsubj -- translate
# artificial general intelligence -- intelligence -- dobj -- demonstrating
# text -- text -- dobj -- translate
# compose -- compose -- conj -- translate
# symphonies -- symphonies -- dobj -- compose
# games -- games -- pobj -- at
# artificial intelligence -- intelligence -- ROOT -- intelligence
# A non-human program -- program -- ROOT -- program
# model -- model -- conj -- program
# sophisticated tasks -- tasks -- dobj -- solve
# example -- example -- pobj -- For
# a program -- program -- nsubj -- text
# model -- model -- conj -- program
# a program -- program -- conj -- text
# model -- model -- conj -- program
# diseases -- diseases -- dobj -- identifies
# radiologic images -- images -- pobj -- from
# artificial intelligence -- intelligence -- dobj -- exhibit
# machine learning -- learning -- nsubj -- is
# a sub-field -- field -- attr -- is
# artificial intelligence -- intelligence -- pobj -- of
# recent years -- years -- pobj -- in
# some organizations -- organizations -- nsubj -- begun
# the terms -- terms -- dative -- using
# #fairness -- fairness -- dobj -- attribute
# Synonym -- Synonym -- appos -- fairness
# feature -- feature -- pobj -- for
# fairness -- fairness -- pobj -- In
# attributes -- attributes -- nsubj -- refer
# characteristics -- characteristics -- pobj -- to
# individuals -- individuals -- pobj -- to
# AUC -- AUC -- ROOT -- AUC
# Area -- Area -- appos -- AUC
# the ROC Curve -- Curve -- pobj -- under
# An evaluation metric -- metric -- ROOT -- metric
# all possible classification thresholds -- thresholds -- dobj -- considers
# The Area -- Area -- nsubj -- is
# the ROC curve -- curve -- pobj -- Under
# the probability -- probability -- attr -- is
# a classifier -- classifier -- nsubj -- be
# a randomly chosen positive example -- example -- nsubj -- is
# a randomly chosen negative example -- example -- nsubj -- is
# reality -- reality -- dobj -- augmented
# A technology -- technology -- ROOT -- technology
# a computer-generated image -- image -- dobj -- superimposes
# a user's view -- view -- pobj -- on
# the real world -- world -- pobj -- of
# a composite view -- view -- dobj -- providing
# automation bias -- bias -- ROOT -- bias
# #fairness -- fairness -- ROOT -- fairness
# a human decision maker -- maker -- nsubj -- favors
# recommendations -- recommendations -- dobj -- favors
# an automated decision-making system -- system -- pobj -- by
# information -- information -- pobj -- over
# automation -- automation -- pobj -- without
# the automated decision-making system -- system -- nsubj -- makes
# errors -- errors -- dobj -- makes
# average precision -- precision -- ROOT -- precision
# A metric -- metric -- ROOT -- metric
# the performance -- performance -- dobj -- summarizing
# a ranked sequence -- sequence -- pobj -- of
# results -- results -- pobj -- of
# Average precision -- precision -- nsubjpass -- calculated
# the average -- average -- dobj -- taking
# the precision values -- values -- pobj -- of
# each relevant result -- result -- pobj -- for
# the ranked list -- list -- pobj -- in
# the recall -- recall -- nsubj -- increases
# the previous result -- result -- pobj -- to
# Area -- Area -- dobj -- See
# the PR Curve -- Curve -- pobj -- under
# B -- B -- ROOT -- B
# backpropagation -- backpropagation -- ROOT -- backpropagation
# The primary algorithm -- algorithm -- ROOT -- algorithm
# gradient descent -- descent -- dobj -- performing
# neural networks -- networks -- pobj -- on
# the output values -- values -- nsubjpass -- calculated
# each node -- node -- pobj -- of
# a forward pass -- pass -- pobj -- in
# the partial derivative -- derivative -- nsubjpass -- calculated
# the error -- error -- pobj -- of
# respect -- respect -- pobj -- with
# each parameter -- parameter -- pobj -- to
# a backward pass -- pass -- pobj -- in
# the graph -- graph -- pobj -- through
# bag -- bag -- ROOT -- bag
# words -- words -- pobj -- of
# A representation -- representation -- ROOT -- representation
# the words -- words -- pobj -- of
# a phrase -- phrase -- pobj -- in
# passage -- passage -- conj -- phrase
# order -- order -- pobj -- of
# example -- example -- pobj -- For
# bag -- bag -- nsubj -- represents
# words -- words -- pobj -- of
# the following three phrases -- phrases -- dobj -- represents
# the dog -- dog -- dobj -- jumps
# dog -- dog -- nsubj -- jumps
# Each word -- word -- nsubjpass -- mapped
# an index -- index -- pobj -- to
# a sparse vector -- vector -- pobj -- in
# the vector -- vector -- nsubj -- has
# an index -- index -- dobj -- has
# every word -- word -- pobj -- for
# the vocabulary -- vocabulary -- pobj -- in
# example -- example -- pobj -- For
# the dog jumps -- jumps -- nsubjpass -- mapped
# a feature vector -- vector -- pobj -- into
# non-zero values -- values -- pobj -- with
# the three indices -- indices -- pobj -- at
# the words -- words -- pobj -- to
# the, dog -- dog -- appos -- words
# The non-zero value -- value -- nsubj -- be
# the following -- following -- pobj -- of
# the presence -- presence -- dobj -- indicate
# a word -- word -- pobj -- of
# A count -- count -- nsubj -- appears
# the number -- number -- pobj -- of
# times -- times -- pobj -- of
# a word -- word -- nsubj -- appears
# the bag -- bag -- pobj -- in
# example -- example -- pobj -- For
# the phrase -- phrase -- nsubj -- were
# the maroon dog -- dog -- nsubj -- is
# a dog -- dog -- attr -- is
# maroon fur -- fur -- pobj -- with
# both maroon -- maroon -- nsubjpass -- represented
# dog -- dog -- conj -- maroon
# the other words -- words -- nsubjpass -- represented
# Some other value -- value -- nsubj -- appears
# the logarithm -- logarithm -- pobj -- as
# the count -- count -- pobj -- of
# the number -- number -- pobj -- of
# times -- times -- pobj -- of
# a word -- word -- nsubj -- appears
# the bag -- bag -- pobj -- in
# baseline -- baseline -- ROOT -- baseline
# A model -- model -- nsubj -- performing
# a reference point -- point -- pobj -- as
# how well another model -- model -- dobj -- comparing
# a more complex one -- one -- nsubj -- performing
# example -- example -- pobj -- For
# a logistic regression model -- model -- nsubj -- serve
# a good baseline -- baseline -- pobj -- as
# a deep model -- model -- pobj -- for
# a particular problem -- problem -- pobj -- For
# the baseline -- baseline -- nsubj -- helps
# model developers -- developers -- nsubj -- quantify
# the minimal expected performance -- performance -- dobj -- quantify
# a new model -- model -- nsubj -- achieve
# the new model -- model -- nsubj -- be
# The set -- set -- ROOT -- set
# examples -- examples -- pobj -- of
# one iteration -- iteration -- pobj -- in
# model training -- training -- pobj -- of
# size -- size -- dobj -- batch
# normalization -- normalization -- dobj -- batch
# the input -- input -- dobj -- Normalizing
# output -- output -- conj -- input
# the activation functions -- functions -- pobj -- of
# a hidden layer -- layer -- pobj -- in
# Batch normalization -- normalization -- nsubj -- provide
# the following benefits -- benefits -- dobj -- provide
# neural networks -- networks -- nsubj -- stable
# outlier weights -- weights -- pobj -- against
# higher learning rates -- rates -- dobj -- Enable
# batch size -- size -- ROOT -- size
# The number -- number -- ROOT -- number
# examples -- examples -- pobj -- of
# a batch -- batch -- pobj -- in
# example -- example -- pobj -- For
# the batch size -- size -- nsubj -- is
# SGD -- SGD -- pobj -- of
# the batch size -- size -- nsubj -- is
# Batch size -- size -- nsubjpass -- fixed
# training -- training -- pobj -- during
# inference -- inference -- conj -- training
# TensorFlow -- TensorFlow -- nsubj -- permit
# dynamic batch sizes -- sizes -- dobj -- permit
# Bayesian neural network -- network -- ROOT -- network
# A probabilistic neural network -- network -- ROOT -- network
# uncertainty -- uncertainty -- pobj -- for
# weights -- weights -- pobj -- in
# outputs -- outputs -- conj -- weights
# A standard neural network regression model -- model -- nsubj -- predicts
# a scalar value -- value -- dobj -- predicts
# example -- example -- pobj -- for
# a model -- model -- nsubj -- predicts
# a house price -- price -- dobj -- predicts
# contrast -- contrast -- pobj -- By
# a Bayesian neural network -- network -- nsubj -- predicts
# a distribution -- distribution -- dobj -- predicts
# values -- values -- pobj -- of
# example -- example -- pobj -- for
# a model -- model -- nsubj -- predicts
# a house price -- price -- dobj -- predicts
# a standard deviation -- deviation -- pobj -- with
# A Bayesian neural network -- network -- nsubj -- relies
# Bayes' Theorem -- Theorem -- pobj -- on
# uncertainties -- uncertainties -- dobj -- calculate
# weights -- weights -- pobj -- in
# predictions -- predictions -- conj -- weights
# A Bayesian neural network -- network -- nsubj -- be
# it -- it -- nsubj -- is
# uncertainty -- uncertainty -- dobj -- quantify
# models -- models -- pobj -- in
# pharmaceuticals -- pharmaceuticals -- pobj -- to
# Bayesian neural networks -- networks -- nsubj -- help
# overfitting -- overfitting -- dobj -- prevent
# Bellman equation -- equation -- ROOT -- equation
# #rl -- rl -- ROOT -- rl
# reinforcement learning -- learning -- pobj -- In
# the optimal Q-function -- function -- pobj -- by
# Reinforcement learning algorithms -- algorithms -- nsubj -- apply
# this identity -- identity -- dobj -- apply
# Q-learning -- learning -- dobj -- create
# the following update rule -- rule -- pobj -- via
# reinforcement learning -- learning -- pobj -- Beyond
# the Bellman equation -- equation -- nsubj -- has
# applications -- applications -- dobj -- has
# dynamic programming -- programming -- pobj -- to
# the Wikipedia entry -- entry -- dobj -- See
# Bellman Equation -- Equation -- pobj -- for
# bias -- bias -- ROOT -- bias
# ethics/fairness -- fairness -- appos -- bias
# #fairness -- fairness -- ROOT -- fairness
# Stereotyping -- Stereotyping -- ROOT -- Stereotyping
# prejudice -- prejudice -- conj -- Stereotyping
# favoritism -- favoritism -- conj -- prejudice
# some things -- things -- pobj -- towards
# people -- people -- conj -- things
# groups -- groups -- conj -- people
# others -- others -- pobj -- over
# These biases -- biases -- nsubj -- affect
# collection -- collection -- dobj -- affect
# interpretation -- interpretation -- conj -- collection
# data -- data -- pobj -- of
# the design -- design -- appos -- collection
# a system -- system -- pobj -- of
# users -- users -- nsubj -- interact
# a system -- system -- pobj -- with
# Forms -- Forms -- nsubj -- include
# this type -- type -- pobj -- of
# bias -- bias -- pobj -- of
# automation bias -- bias -- ROOT -- bias
# confirmation bias -- bias -- ROOT -- bias
# experimenter -- experimenter -- ROOT -- experimenter
# bias
# group attribution bias -- bias -- ROOT -- bias
# implicit bias -- bias -- ROOT -- bias
# group -- group -- pobj -- in
# out-group homogeneity bias -- bias -- conj -- bias
# Systematic error -- error -- ROOT -- error
# a sampling or reporting procedure -- procedure -- pobj -- by
# Forms -- Forms -- nsubj -- include
# this type -- type -- pobj -- of
# bias -- bias -- pobj -- of
# coverage bias -- bias -- dobj -- include
# non-response bias -- bias -- ROOT -- bias
# participation bias -- bias -- ROOT -- bias
# reporting bias -- bias -- ROOT -- bias
# sampling bias -- bias -- ROOT -- bias
# selection bias -- bias -- nsubjpass -- confused
# the bias term -- term -- pobj -- with
# machine learning models -- models -- pobj -- in
# prediction bias -- bias -- conj -- models
# bias -- bias -- ROOT -- bias
# math -- math -- appos -- bias
# An intercept -- intercept -- ROOT -- intercept
# an origin -- origin -- pobj -- from
# Bias -- Bias -- nsubjpass -- referred
# the bias term -- term -- pobj -- as
# b -- b -- pobj -- as
# w0 -- w0 -- conj -- b
# machine learning models -- models -- pobj -- in
# example -- example -- pobj -- For
# bias -- bias -- nsubj -- is
# the b -- b -- attr -- is
# the following formula -- formula -- pobj -- in
# bias -- bias -- pobj -- with
# ethics -- ethics -- pobj -- in
# fairness or prediction bias -- bias -- conj -- ethics
# bigram -- bigram -- ROOT -- bigram
# An N-gram -- gram -- ROOT -- gram
# binary classification -- classification -- ROOT -- classification
# A type -- type -- ROOT -- type
# classification task -- task -- pobj -- of
# two mutually exclusive classes -- classes -- pobj -- of
# example -- example -- pobj -- For
# a machine learning model -- model -- nsubj -- is
# email messages -- messages -- dobj -- evaluates
# outputs -- outputs -- conj -- messages
# either "spam -- spam -- dobj -- outputs
# "not spam -- spam -- conj -- spam
# a binary classifier -- classifier -- attr -- is
# bucketing -- bucketing -- dobj -- See
# A machine learning technique -- technique -- ROOT -- technique
# a set -- set -- dobj -- combines
# simple and not very accurate classifiers -- classifiers -- pobj -- of
# "weak" classifiers -- classifiers -- pobj -- as
# a classifier -- classifier -- pobj -- into
# high accuracy -- accuracy -- pobj -- with
# (a "strong" classifier -- classifier -- appos -- technique
# the examples -- examples -- dobj -- upweighting
# the model -- model -- nsubj -- misclassfying
# box -- box -- dobj -- bounding
# an image -- image -- pobj -- In
# a rectangle -- rectangle -- pobj -- of
# an area -- area -- pobj -- around
# interest -- interest -- pobj -- of
# the dog -- dog -- pobj -- as
# the image -- image -- pobj -- in
# Photograph -- Photograph -- ROOT -- Photograph
# a dog -- dog -- pobj -- of
# a sofa -- sofa -- pobj -- on
# A green bounding box -- box -- ROOT -- box
# top-left coordinates -- coordinates -- pobj -- with
# bottom-right -- right -- ROOT -- right
# coordinates -- coordinates -- nsubj -- circumscribes
# the dog's body -- body -- dobj -- circumscribes
# the shape -- shape -- dobj -- Expanding
# an operand -- operand -- pobj -- of
# a matrix math operation -- operation -- pobj -- in
# dimensions -- dimensions -- pobj -- to
# that operation -- operation -- pobj -- for
# instance -- instance -- pobj -- For
# linear algebra -- algebra -- nsubj -- requires
# the two operands -- operands -- nsubj -- have
# a matrix addition operation -- operation -- pobj -- in
# the same dimensions -- dimensions -- dobj -- have
# you -- you -- nsubj -- add
# a matrix -- matrix -- dobj -- add
# shape -- shape -- pobj -- of
# m -- m -- appos -- shape
# n -- n -- appos -- shape
# a vector -- vector -- pobj -- to
# length n. Broadcasting -- Broadcasting -- pobj -- of
# this operation -- operation -- dobj -- enables
# the vector -- vector -- dobj -- expanding
# length n -- n -- pobj -- of
# a matrix -- matrix -- pobj -- to
# shape -- shape -- pobj -- of
# m -- m -- appos -- shape
# n -- n -- appos -- shape
# the same values -- values -- dobj -- replicating
# each column -- column -- pobj -- down
# example -- example -- pobj -- For
# the following definitions -- definitions -- pobj -- given
# linear algebra -- algebra -- nsubj -- prohibits
# A -- A -- nsubj -- have
# B -- B -- conj -- A
# different dimensions -- dimensions -- dobj -- have
# B -- B -- ROOT -- B
# broadcasting -- broadcasting -- nsubj -- enables
# the operation -- operation -- dobj -- enables
# B -- B -- dobj -- expanding
# A+B -- A+B -- nsubj -- is
# a valid operation -- operation -- attr -- is
# the following description -- description -- dobj -- See
# NumPy -- NumPy -- pobj -- in
# more details -- details -- pobj -- for
# multiple binary features -- features -- pobj -- into
# value range -- range -- pobj -- on
# example -- example -- pobj -- For
# temperature -- temperature -- dobj -- representing
# a single continuous floating-point feature -- feature -- pobj -- as
# you -- you -- nsubj -- chop
# ranges -- ranges -- dobj -- chop
# temperatures -- temperatures -- pobj -- of
# discrete bins -- bins -- pobj -- into
# temperature data -- data -- pobj -- Given
# a tenth -- tenth -- pobj -- to
# a degree -- degree -- pobj -- of
# all temperatures between 0.0 and 15.0 degrees -- degrees -- nsubjpass -- put
# one bin -- bin -- pobj -- into
# 15.1 to 30.0 degrees -- degrees -- nsubj -- be
# a second bin -- bin -- attr -- be
# 30.1 to 50.0 degrees -- degrees -- nsubj -- be
# a third bin -- bin -- attr -- be
# C
# calibration layer -- layer -- ROOT -- layer
# A post-prediction adjustment -- adjustment -- nsubj -- account
# prediction bias -- bias -- pobj -- for
# The adjusted predictions -- predictions -- nsubj -- match
# probabilities -- probabilities -- conj -- predictions
# the distribution -- distribution -- dobj -- match
# an observed set -- set -- pobj -- of
# labels -- labels -- pobj -- of
# candidate generation -- generation -- ROOT -- generation
# The initial set -- set -- ROOT -- set
# recommendations -- recommendations -- pobj -- of
# a recommendation system -- system -- pobj -- by
# example -- example -- pobj -- For
# a bookstore -- bookstore -- dobj -- consider
# 100,000 titles -- titles -- dobj -- offers
# The candidate generation phase -- phase -- nsubj -- creates
# a much smaller list -- list -- dobj -- creates
# suitable books -- books -- pobj -- of
# a particular user -- user -- pobj -- for
# even 500 books -- books -- nsubj -- is
# a user -- user -- pobj -- to
# Subsequent, more expensive, phases -- phases -- nsubj -- whittle
# a recommendation system -- system -- pobj -- of
# a much smaller, more useful set -- set -- pobj -- to
# recommendations -- recommendations -- pobj -- of
# candidate -- candidate -- ROOT -- candidate
# sampling -- sampling -- dobj -- candidate
# A training-time optimization -- optimization -- ROOT -- optimization
# a probability -- probability -- nsubjpass -- calculated
# all the positive labels -- labels -- pobj -- for
# example -- example -- pobj -- for
# a random sample -- sample -- pobj -- for
# negative labels -- labels -- pobj -- of
# example -- example -- pobj -- For
# we -- we -- nsubj -- have
# an example -- example -- dobj -- have
# the predicted probabilities -- probabilities -- dobj -- have
# corresponding loss terms -- terms -- conj -- probabilities
# the beagle and dog class outputs -- outputs -- pobj -- for
# addition -- addition -- pobj -- in
# a random subset -- subset -- pobj -- to
# the remaining classes -- classes -- pobj -- of
# cat -- cat -- appos -- classes
# lollipop -- lollipop -- conj -- cat
# fence -- fence -- appos -- classes
# The idea -- idea -- nsubj -- is
# the negative classes -- classes -- nsubj -- learn
# less frequent negative reinforcement -- reinforcement -- pobj -- from
# positive classes -- classes -- nsubj -- get
# proper positive reinforcement -- reinforcement -- dobj -- get
# The motivation -- motivation -- nsubj -- is
# candidate sampling -- sampling -- pobj -- for
# a computational efficiency win -- win -- attr -- is
# predictions -- predictions -- dobj -- computing
# all negatives -- negatives -- pobj -- for
# categorical data -- data -- ROOT -- data
# Features -- Features -- nsubj -- having
# a discrete set -- set -- dobj -- having
# possible values -- values -- pobj -- of
# example -- example -- pobj -- For
# a categorical feature -- feature -- dobj -- consider
# a discrete set -- set -- dobj -- has
# three possible values -- values -- pobj -- of
# Tudor -- Tudor -- appos -- style
# ranch -- ranch -- conj -- Tudor
# colonial -- colonial -- conj -- ranch
# house style -- style -- dobj -- representing
# categorical data -- data -- pobj -- as
# the model -- model -- nsubj -- learn
# the separate impacts -- impacts -- dobj -- learn
# Tudor -- Tudor -- pobj -- of
# ranch -- ranch -- conj -- Tudor
# colonial -- colonial -- conj -- ranch
# house price -- price -- pobj -- on
# values -- values -- nsubj -- are
# the discrete set -- set -- pobj -- in
# only one value -- value -- nsubjpass -- applied
# a given example -- example -- pobj -- to
# example -- example -- pobj -- For
# a car maker categorical feature -- feature -- nsubj -- permit
# only a single value -- value -- dobj -- permit
# Toyota -- Toyota -- appos -- value
# example -- example -- pobj -- per
# more than one value -- value -- nsubj -- be
# A single car -- car -- nsubjpass -- painted
# more than one different color -- color -- dobj -- painted
# a car color categorical feature -- feature -- nsubj -- permit
# a single example -- example -- dobj -- permit
# multiple values -- values -- dobj -- have
# example -- example -- pobj -- for
# Categorical features -- features -- nsubjpass -- called
# Contrast -- Contrast -- ROOT -- Contrast
# numerical data -- data -- pobj -- with
# centroid -- centroid -- ROOT -- centroid
# The center -- center -- ROOT -- center
# a cluster -- cluster -- pobj -- of
# a k-means -- means -- pobj -- by
# k-median algorithm -- algorithm -- conj -- means
# instance -- instance -- pobj -- For
# k -- k -- nsubj -- is
# the k-means -- means -- nsubj -- finds
# k-median algorithm -- algorithm -- conj -- means
# 3 centroids -- centroids -- dobj -- finds
# A category -- category -- ROOT -- category
# algorithms -- algorithms -- dobj -- clustering
# data -- data -- dobj -- organizes
# nonhierarchical clusters -- clusters -- pobj -- into
# k-means -- means -- nsubj -- is
# the most widely used centroid-based clustering algorithm -- algorithm -- attr -- is
# Contrast -- Contrast -- ROOT -- Contrast
# hierarchical clustering algorithms -- algorithms -- pobj -- with
# checkpoint -- checkpoint -- ROOT -- checkpoint
# Data -- Data -- ROOT -- Data
# the state -- state -- dobj -- captures
# the variables -- variables -- pobj -- of
# a model -- model -- pobj -- of
# a particular time -- time -- pobj -- at
# Checkpoints -- Checkpoints -- nsubj -- enable
# exporting model weights -- weights -- dobj -- enable
# training -- training -- dobj -- performing
# multiple sessions -- sessions -- pobj -- across
# Checkpoints -- Checkpoints -- nsubj -- enable
# training -- training -- dobj -- enable
# past errors -- errors -- dobj -- continue
# example -- example -- pobj -- for
# the graph -- graph -- nsubjpass -- included
# itself -- itself -- appos -- graph
# a checkpoint -- checkpoint -- pobj -- in
# class -- class -- ROOT -- class
# a set -- set -- pobj -- of
# enumerated target values -- values -- pobj -- of
# a label -- label -- pobj -- for
# example -- example -- pobj -- For
# a binary classification model -- model -- pobj -- in
# spam -- spam -- dobj -- detects
# the two classes -- classes -- nsubj -- are
# a multi-class classification model -- model -- pobj -- In
# dog breeds -- breeds -- dobj -- identifies
# the classes -- classes -- nsubj -- be
# classification model -- model -- ROOT -- model
# A type -- type -- ROOT -- type
# machine learning model -- model -- pobj -- of
# two or more discrete classes -- classes -- pobj -- among
# example -- example -- pobj -- For
# a natural language processing classification model -- model -- nsubj -- determine
# an input sentence -- sentence -- nsubj -- was
# French -- French -- pobj -- in
# regression model -- model -- pobj -- with
# classification threshold -- threshold -- ROOT -- threshold
# A scalar-value criterion -- criterion -- ROOT -- criterion
# a model's predicted score -- score -- pobj -- to
# order -- order -- pobj -- in
# the positive class -- class -- dobj -- separate
# the negative class -- class -- pobj -- from
# logistic regression -- regression -- dobj -- mapping
# binary classification -- classification -- pobj -- to
# example -- example -- pobj -- For
# a logistic regression model -- model -- dobj -- consider
# the probability -- probability -- nsubj -- being
# a given email message -- message -- pobj -- of
# the classification threshold -- threshold -- nsubj -- is
# logistic regression values -- values -- nsubjpass -- classified
# spam -- spam -- pobj -- as
# not spam -- spam -- pobj -- as
# class-imbalanced dataset -- dataset -- ROOT -- dataset
# A binary classification problem -- problem -- ROOT -- problem
# the labels -- labels -- nsubj -- have
# the two classes -- classes -- pobj -- for
# significantly different frequencies -- frequencies -- dobj -- have
# example -- example -- pobj -- For
# a disease -- disease -- nsubj -- dataset
# examples -- examples -- pobj -- of
# positive labels -- labels -- dobj -- have
# negative labels -- labels -- nsubj -- is
# a class-imbalanced problem -- problem -- attr -- is
# examples -- examples -- pobj -- of
# one team -- team -- dobj -- label
# the other team -- team -- nsubj -- winning
# a class-imbalanced problem -- problem -- attr -- is
# A technique -- technique -- ROOT -- technique
# outliers -- outliers -- dobj -- handling
# feature values -- values -- dobj -- reducing
# a set maximum value -- value -- pobj -- than
# that maximum value -- value -- pobj -- to
# feature values -- values -- dobj -- increasing
# a specific minimum value -- value -- pobj -- than
# that minimum value -- value -- pobj -- to
# example -- example -- pobj -- For
# only a few feature values -- values -- nsubj -- fall
# the range 40–60 -- 40–60 -- pobj -- outside
# this case -- case -- pobj -- In
# you -- you -- nsubj -- do
# all values -- values -- dobj -- Clip
# all values -- values -- dobj -- Clip
# addition -- addition -- pobj -- In
# input values -- values -- dobj -- bringing
# a designated range -- range -- pobj -- within
# gradient values -- values -- dobj -- force
# a designated range -- range -- pobj -- within
# training -- training -- pobj -- during
# Cloud TPU -- TPU -- ROOT -- TPU

# %%
# Finding a verb with a subject from below — good

from spacy.symbols import nsubj, VERB


verbs = set()
for possible_subject in doc:
    if possible_subject.dep == nsubj and possible_subject.head.pos == VERB:
        verbs.add(possible_subject.head)
print(verbs)
# Out:
# {performs, appears, label, jumps, performing, offers, identifies, refer, makes, begun, solve, predicts, interact, learns, chop, determines, uses, increases, circumscribes, identifies, affect, needs, helps, captures, fall, translates, relies, finds, account, get, prohibits, translate, represents, permit, permit, enable, winning, include, takes, accounts, provide, quantify, predicts, learn, determine, dataset, chooses, include, enables, apply, used, favors, combines, requires, predicts, organizes, predicts, aims, learn, match, permit, detects, having, serve, creates, superimposes, evaluates, chooses, See, misclassfying, enable, rescales, achieve, help, add, seeks, considers, considers, got, outputs, appears, demonstrates}

# %% [markdown]
# ## Disabling the parser
#
# #Examples
#
# ```python
# nlp = spacy.load("en_core_web_sm", disable=["parser"])
# nlp = English().from_disk("/model", disable=["parser"])
# doc = nlp("I don't want parsed", disable=["parser"])
# ```

# %% [markdown]
# ## Named Entity Recognition

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("San Francisco considers banning sidewalk delivery robots")

# document level
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print(ents)

# token level
ent_san = [doc[0].text, doc[0].ent_iob_, doc[0].ent_type_]
ent_francisco = [doc[1].text, doc[1].ent_iob_, doc[1].ent_type_]
print(ent_san)  # ['San', 'B', 'GPE']
print(ent_francisco)  # ['Francisco', 'I', 'GPE']
# Out:
# [('San Francisco', 0, 13, 'GPE')]
# ['San', 'B', 'GPE']
# ['Francisco', 'I', 'GPE']

# %%
import spacy
from spacy.tokens import Span

nlp = spacy.load("en_core_web_sm")
doc = nlp("fb is hiring a new vice president of global policy")
ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print('Before', ents)
# the model didn't recognise "fb" as an entity :(

fb_ent = Span(doc, 0, 1, label="ORG") # create a Span for the new entity
doc.ents = list(doc.ents) + [fb_ent]

ents = [(e.text, e.start_char, e.end_char, e.label_) for e in doc.ents]
print('After', ents)
# [('fb', 0, 2, 'ORG')] 🎉
# Out:
# Before []
# After [('fb', 0, 2, 'ORG')]
